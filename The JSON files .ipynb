# %%
import json
import pandas as pd

# Load the JSON file as a string
with open('airlines-1558527599826.json', 'r') as f:    #only the first JSON file 
    json_str = f.read()

# Split the string into a list of JSON objects
json_objs = json_str.split('\n')

# Parse each JSON object in the list and append to a list of dictionaries
dict_list = []
for json_obj in json_objs:
    if json_obj.strip() == '':
        continue
    dict_list.append(json.loads(json_obj))

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(dict_list)
df
# Out:
#                            created_at            id               id_str  \
# 0      Wed May 22 12:20:00 +0000 2019  1.131173e+18  1131172858951024641
# 1      Wed May 22 12:20:01 +0000 2019  1.131173e+18  1131172864147808257
# 2      Wed May 22 12:20:02 +0000 2019  1.131173e+18  1131172867985485824
# 3      Wed May 22 12:20:12 +0000 2019  1.131173e+18  1131172909463027720
# 4      Wed May 22 12:20:28 +0000 2019  1.131173e+18  1131172975682605058
# ...                               ...           ...                  ...
# 14384  Thu May 23 11:42:26 +0000 2019  1.131526e+18  1131525791429402625
# 14385  Thu May 23 11:42:27 +0000 2019  1.131526e+18  1131525795804045312
# 14386  Thu May 23 11:42:27 +0000 2019  1.131526e+18  1131525797313949698
# 14387  Thu May 23 11:42:35 +0000 2019  1.131526e+18  1131525832500031490
# 14388  Thu May 23 11:42:44 +0000 2019  1.131526e+18  1131525868495474688
#
#                                                     text display_text_range  \
# ...

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'display_text_range',
#  'source',
#  'truncated',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'quote_count',
#  'reply_count',
#  'retweet_count',
#  'favorite_count',
#  'entities',
#  'extended_entities',
#  'favorited',
#  'retweeted',
#  'possibly_sensitive',
#  'filter_level',
#  'lang',
#  'timestamp_ms',
#  'retweeted_status',
#  'extended_tweet',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'quoted_status',
#  'quoted_status_permalink',
#  'delete']

# %%
#df.to_excel(r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\Year1-Q4\DBL challenge\dataframe.xlsx', index=False)

# %%
import json
import pandas as pd

# Load the JSON file as a string
with open('airlines-1558546003827.json', 'r') as f:    #only the first JSON file 
    json_str = f.read()

# Split the string into a list of JSON objects
json_objs = json_str.split('\n')

# Parse each JSON object in the list and append to a list of dictionaries
dict_list = []
for json_obj in json_objs:
    if json_obj.strip() == '':
        continue
    dict_list.append(json.loads(json_obj))

# Convert the list of dictionaries to a Pandas DataFrame
df2 = pd.DataFrame(dict_list)
df2
# Out:
#                            created_at            id               id_str  \
# 0      Wed May 22 17:26:43 +0000 2019  1.131250e+18  1131250045985050624
# 1      Wed May 22 17:26:52 +0000 2019  1.131250e+18  1131250086355329029
# 2      Wed May 22 17:26:53 +0000 2019  1.131250e+18  1131250089320681472
# 3      Wed May 22 17:26:55 +0000 2019  1.131250e+18  1131250095662481408
# 4      Wed May 22 17:26:55 +0000 2019  1.131250e+18  1131250099294810113
# ...                               ...           ...                  ...
# 14134  Thu May 23 14:54:29 +0000 2019  1.131574e+18  1131574125619765251
# 14135  Thu May 23 14:54:32 +0000 2019  1.131574e+18  1131574135015006209
# 14136  Thu May 23 14:54:33 +0000 2019  1.131574e+18  1131574142241726466
# 14137  Thu May 23 14:54:40 +0000 2019  1.131574e+18  1131574168699457536
# 14138  Thu May 23 14:54:44 +0000 2019  1.131574e+18  1131574187569631232
#
#                                                     text display_text_range  \
# ...

# %%
df2.to_excel(r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\Year1-Q4\DBL challenge\dataframe2.xlsx', index=False)
